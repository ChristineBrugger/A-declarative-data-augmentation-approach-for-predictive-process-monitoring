# %%
# Import necessary script
from scripts.dda_functions import EventLogProcessor

# %% [markdown]
# # Declarative Data Augmentation
# We present our declarative data augmentation approach in this notebook. Every step that is necessary to generate synthetic data, which can then be used to augment the original data will be presented and explained here.

# %% [markdown]
# ## Helpdesk

# %%
# Initialize EventLogProcessor class for Helpdesk 
helpdesk = event_processor = EventLogProcessor("helpdesk")

# Apply Train-Test Split
helpdesk.train_test_split()

# Convert train data to an event log
helpdesk.generate_train_log()
# Out:
# exporting log, completed traces ::   0%|          | 0/3664 [00:00<?, ?it/s]

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
helpdesk.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)
# Out:
# parsing log, completed traces ::   0%|          | 0/3664 [00:00<?, ?it/s]
# Computing discovery ...
# Model activities:
# -----------------
# 0 Assign seriousness
# 1 Take in charge ticket
# 2 Resolve ticket
# 3 Closed
# 4 Insert ticket
# 5 Wait
# 6 Create SW anomaly
# 7 Require upgrade
# 8 Resolve SW anomaly
# 9 Schedule intervention
# 10 RESOLVED
# 11 INVALID
# 12 VERIFIED
#
#
# Model constraints:
# -----------------
# 0 Existence1[Resolve ticket] | |
# 1 Existence1[Closed] | |
# 2 Absence2[Closed] | |
# 3 Exactly1[Closed] | |
# 4 End[Closed] | |
# 5 Existence1[Assign seriousness] | |
# 6 Init[Assign seriousness] | |
# 7 Choice[Resolve ticket, Closed] | | |
# 8 Choice[Closed, Resolve ticket] | | |
# 9 Responded Existence[Resolve ticket, Closed] | | |
# 10 Responded Existence[Closed, Resolve ticket] | | |
# 11 Response[Resolve ticket, Closed] | | |
# 12 Precedence[Resolve ticket, Closed] | | |
# 13 Alternate Precedence[Resolve ticket, Closed] | | |
# 14 Chain Precedence[Resolve ticket, Closed] | | |
# 15 Not Response[Closed, Resolve ticket] | | |
# 16 Not Precedence[Closed, Resolve ticket] | | |
# 17 Not Chain Response[Closed, Resolve ticket] | | |
# 18 Not Chain Precedence[Closed, Resolve ticket] | | |
# 19 Choice[Resolve ticket, Assign seriousness] | | |
# 20 Choice[Assign seriousness, Resolve ticket] | | |
# 21 Responded Existence[Resolve ticket, Assign seriousness] | | |
# 22 Responded Existence[Assign seriousness, Resolve ticket] | | |
# 23 Response[Assign seriousness, Resolve ticket] | | |
# 24 Precedence[Assign seriousness, Resolve ticket] | | |
# 25 Not Response[Resolve ticket, Assign seriousness] | | |
# 26 Not Precedence[Resolve ticket, Assign seriousness] | | |
# 27 Not Chain Response[Resolve ticket, Assign seriousness] | | |
# 28 Not Chain Precedence[Resolve ticket, Assign seriousness] | | |
# 29 Choice[Assign seriousness, Closed] | | |
# 30 Choice[Closed, Assign seriousness] | | |
# 31 Responded Existence[Assign seriousness, Closed] | | |
# 32 Responded Existence[Closed, Assign seriousness] | | |
# 33 Response[Assign seriousness, Closed] | | |
# 34 Precedence[Assign seriousness, Closed] | | |
# 35 Alternate Precedence[Assign seriousness, Closed] | | |
# 36 Not Response[Closed, Assign seriousness] | | |
# 37 Not Precedence[Closed, Assign seriousness] | | |
# 38 Not Chain Response[Assign seriousness, Closed] | | |
# 39 Not Chain Response[Closed, Assign seriousness] | | |
# 40 Not Chain Precedence[Assign seriousness, Closed] | | |
# 41 Not Chain Precedence[Closed, Assign seriousness] | | |

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For Helpdesk we define:
# * number of required mean values: 1
# * consider business hours: True
# * consider weekday: True

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = helpdesk.get_syn_log_parameters()

# Simulate declarative process model
helpdesk.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
helpdesk.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = helpdesk.generate_timedelta(1)

# Get case arrival distribution
inter_case_dist = helpdesk.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = helpdesk.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
helpdesk.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=True, consider_day=True)
# Out:
# DEBUG:ASP generator:Distribution for traces uniform
# DEBUG:ASP generator:traces: 3664, events can have a trace min(2) max(15)
# INFO:ASP generator:Computing distribution
# DEBUG:Distributor:Distribution() uniform min_mu: 2 max_sigma: 15 num_traces: 3664 custom_prob: None
# DEBUG:Distributor:Uniform() probabilities: [Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14)]
#     Number of Events  Number of Cases
# 0                  2                1
# 1                  3              169
# 2                  4             2158
# 3                  5              717
# 4                  6              354
# 5                  7              137
# 6                  8               81
# 7                  9               20
# 8                 10               12
# 9                 11                7
# 10                12                4
# 11                13                2
# 12                14                1
# 13                15                1
# DEBUG:Distributor:Custom_dist() min_mu:2 max_sigma:15 num_traces:3664
# DEBUG:Distributor:Probabilities sum 1
# DEBUG:Distributor:Distribution result: [ 3  9 13 ...  7  6  2]
# INFO:ASP generator:Distribution result Counter({11: 301, 7: 276, 4: 276, 5: 274, 15: 268, 14: 264, 12: 263, 6: 260, 10: 256, 3: 253, 2: 251, 9: 249, 13: 238, 8: 235})
# DEBUG:ASP generator:Using custom traces length
# INFO:ASP generator:Computing distribution
# DEBUG:Distributor:Distribution() custom min_mu: 2 max_sigma: 15 num_traces: 3664 custom_prob: [0.0002729258, 0.0461244541, 0.5889737991, 0.1956877729, 0.0966157205, 0.0373908297, 0.0221069869, 0.0054585153, 0.0032751092, 0.0019104803, 0.0010917031, 0.0005458515, 0.0002729258, 0.000272925800000111]
# DEBUG:Distributor:Custom_dist() min_mu:2 max_sigma:15 num_traces:3664
# DEBUG:Distributor:Probabilities sum 1.0
# DEBUG:Distributor:Distribution result: [4 4 5 ... 4 7 4]
# INFO:ASP generator:Distribution result Counter({4: 2211, 5: 676, 6: 337, 7: 161, 3: 156, 8: 74, 10: 17, 9: 17, 12: 5, 13: 3, 11: 3, 2: 2, 14: 1, 15: 1})
# INFO:ASP generator:Computing distribution
# DEBUG:ASP generator:Generating traces
# DEBUG:ASP generator:Translate declare model to ASP
# DEBUG:ASP generator:Declare model translated to ASP. Total Facts 13
# DEBUG:ASP generator:ASP encoding generated
# DEBUG:ASP generator:Start generating traces: Counter({4: 2211, 5: 676, 6: 337, 7: 161, 3: 156, 8: 74, 10: 17, 9: 17, 12: 5, 13: 3, 11: 3, 2: 2, 14: 1, 15: 1})
# DEBUG:ASP generator: Total trace to generate and events: Traces:2211, Events: 4, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(1/2211) with length:4), Seed 3978756281
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(2/2211) with length:4), Seed 1152603821
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(3/2211) with length:4), Seed 3926640173
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:4/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(4/2211) with length:4), Seed 3978272300
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:5/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(5/2211) with length:4), Seed 1597047012
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:6/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(6/2211) with length:4), Seed 725185726
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:7/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(7/2211) with length:4), Seed 3785833798
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:8/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(8/2211) with length:4), Seed 31241269
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:9/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(9/2211) with length:4), Seed 1930439835
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:10/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(10/2211) with length:4), Seed 4238682359
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:11/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(11/2211) with length:4), Seed 3367949296
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:12/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(12/2211) with length:4), Seed 1825288159
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:13/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(13/2211) with length:4), Seed 2896821128
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:14/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(14/2211) with length:4), Seed 992814487
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:15/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(15/2211) with length:4), Seed 3533859186
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:16/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(16/2211) with length:4), Seed 3112561516
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:17/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(17/2211) with length:4), Seed 1142665744
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:18/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(18/2211) with length:4), Seed 1860691467
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:19/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(19/2211) with length:4), Seed 1639172183
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:20/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(20/2211) with length:4), Seed 3400588062
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:21/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(21/2211) with length:4), Seed 1090077354
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:22/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(22/2211) with length:4), Seed 1802701551
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:23/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(23/2211) with length:4), Seed 203441899
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:24/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(24/2211) with length:4), Seed 79175928
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:25/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(25/2211) with length:4), Seed 2483491110
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:26/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(26/2211) with length:4), Seed 3027535282
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:27/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(27/2211) with length:4), Seed 124432056
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:28/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(28/2211) with length:4), Seed 2791752848
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:29/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(29/2211) with length:4), Seed 364666429
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:30/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(30/2211) with length:4), Seed 3006534138
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:31/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(31/2211) with length:4), Seed 1669026873
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:32/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(32/2211) with length:4), Seed 1116729346
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:33/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(33/2211) with length:4), Seed 4037549396
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:34/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(34/2211) with length:4), Seed 82961084
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:35/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(35/2211) with length:4), Seed 3515390514
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:36/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(36/2211) with length:4), Seed 1101628448
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:37/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(37/2211) with length:4), Seed 2760149688
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:38/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(38/2211) with length:4), Seed 385952517
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:39/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(39/2211) with length:4), Seed 1650915183
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:40/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(40/2211) with length:4), Seed 1289147808
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:41/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(41/2211) with length:4), Seed 4047260827
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:42/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(42/2211) with length:4), Seed 4154205213
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:43/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(43/2211) with length:4), Seed 3159742524
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:44/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(44/2211) with length:4), Seed 3401610491
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:45/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(45/2211) with length:4), Seed 1353621826
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:46/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(46/2211) with length:4), Seed 1653317479
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:47/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(47/2211) with length:4), Seed 2237804374
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:48/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(48/2211) with length:4), Seed 1325259556
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:49/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(49/2211) with length:4), Seed 3941984250
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:50/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(50/2211) with length:4), Seed 2882879067
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:51/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(51/2211) with length:4), Seed 3539391702
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:52/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(52/2211) with length:4), Seed 3435116980
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:53/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(53/2211) with length:4), Seed 2399423539
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:54/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(54/2211) with length:4), Seed 1045257867
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:55/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(55/2211) with length:4), Seed 2561092833
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:56/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(56/2211) with length:4), Seed 2878115019
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:57/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(57/2211) with length:4), Seed 2959399698
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:58/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(58/2211) with length:4), Seed 2292286416
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:59/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(59/2211) with length:4), Seed 163516923
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:60/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(60/2211) with length:4), Seed 1687338444
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:61/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(61/2211) with length:4), Seed 1752597157
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:62/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(62/2211) with length:4), Seed 899661461
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:63/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(63/2211) with length:4), Seed 519529583
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:64/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(64/2211) with length:4), Seed 613573239
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:65/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(65/2211) with length:4), Seed 2142304641
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:66/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(66/2211) with length:4), Seed 3468128602
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:67/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(67/2211) with length:4), Seed 4243624065
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:68/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(68/2211) with length:4), Seed 3245112462
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:69/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(69/2211) with length:4), Seed 3347524256
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:70/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(70/2211) with length:4), Seed 2977992624
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:71/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(71/2211) with length:4), Seed 414159346
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:72/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(72/2211) with length:4), Seed 1317003939
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:73/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(73/2211) with length:4), Seed 2870529799
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:74/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(74/2211) with length:4), Seed 2533124612
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:75/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(75/2211) with length:4), Seed 365194262
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:76/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(76/2211) with length:4), Seed 4160809310
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:77/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(77/2211) with length:4), Seed 440767469
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:78/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(78/2211) with length:4), Seed 2891753258
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:79/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(79/2211) with length:4), Seed 2213740637
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:80/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(80/2211) with length:4), Seed 3614584073
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:81/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(81/2211) with length:4), Seed 213634038
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:82/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(82/2211) with length:4), Seed 4153795478
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:83/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(83/2211) with length:4), Seed 1546874293
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:84/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(84/2211) with length:4), Seed 1589397039
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:85/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(85/2211) with length:4), Seed 2108083727
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:86/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(86/2211) with length:4), Seed 3208125445
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:87/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(87/2211) with length:4), Seed 3884006851
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:88/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(88/2211) with length:4), Seed 4179252321
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:89/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(89/2211) with length:4), Seed 2533405266
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:90/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(90/2211) with length:4), Seed 140057327
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:91/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(91/2211) with length:4), Seed 1462666971
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:92/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(92/2211) with length:4), Seed 2940291096
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:93/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(93/2211) with length:4), Seed 3720966077
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:94/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(94/2211) with length:4), Seed 1574930879
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:95/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(95/2211) with length:4), Seed 1074840514
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:96/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(96/2211) with length:4), Seed 3758485273
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:97/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(97/2211) with length:4), Seed 150443304
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:98/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(98/2211) with length:4), Seed 2512599720
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:99/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(99/2211) with length:4), Seed 942156471
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:100/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(100/2211) with length:4), Seed 965390528
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:101/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(101/2211) with length:4), Seed 2701419851
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:102/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(102/2211) with length:4), Seed 2369602832
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:103/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(103/2211) with length:4), Seed 3772526178
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:104/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(104/2211) with length:4), Seed 552549629
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:105/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(105/2211) with length:4), Seed 3698494833
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:106/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(106/2211) with length:4), Seed 89570184
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:107/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(107/2211) with length:4), Seed 633267461
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:108/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(108/2211) with length:4), Seed 3680946613
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:109/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(109/2211) with length:4), Seed 3985429321
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:110/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(110/2211) with length:4), Seed 2924410899
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:111/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(111/2211) with length:4), Seed 854527336
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:112/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(112/2211) with length:4), Seed 891294008
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:113/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(113/2211) with length:4), Seed 4262377024
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:114/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(114/2211) with length:4), Seed 4116676947
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:115/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(115/2211) with length:4), Seed 736496350
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:116/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(116/2211) with length:4), Seed 832352546
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:117/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(117/2211) with length:4), Seed 2275241419
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:118/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(118/2211) with length:4), Seed 2364851308
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:119/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(119/2211) with length:4), Seed 262969407
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:120/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(120/2211) with length:4), Seed 2843719872
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:121/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(121/2211) with length:4), Seed 3356584231
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:122/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(122/2211) with length:4), Seed 3015460854
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:123/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(123/2211) with length:4), Seed 1689965606
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:124/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(124/2211) with length:4), Seed 2364736987
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:125/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(125/2211) with length:4), Seed 832591098
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:126/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(126/2211) with length:4), Seed 2355439046
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:127/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(127/2211) with length:4), Seed 3830924297
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:128/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(128/2211) with length:4), Seed 1676150253
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:129/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(129/2211) with length:4), Seed 1924757223
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:130/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(130/2211) with length:4), Seed 2969975843
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:131/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(131/2211) with length:4), Seed 784148097
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:132/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(132/2211) with length:4), Seed 3203440080
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:133/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(133/2211) with length:4), Seed 1866154141
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:134/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(134/2211) with length:4), Seed 4078132451
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:135/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(135/2211) with length:4), Seed 3757762475
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:136/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(136/2211) with length:4), Seed 673563187
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:137/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(137/2211) with length:4), Seed 3689143298
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:138/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(138/2211) with length:4), Seed 3944411557
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:139/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(139/2211) with length:4), Seed 557433279
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:140/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(140/2211) with length:4), Seed 4076137002
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:141/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(141/2211) with length:4), Seed 3914701736
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:142/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(142/2211) with length:4), Seed 13527542
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:143/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(143/2211) with length:4), Seed 1783603741
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:144/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(144/2211) with length:4), Seed 2259924462
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:145/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(145/2211) with length:4), Seed 2897229104
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:146/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(146/2211) with length:4), Seed 1528771729
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_3,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:147/2211 with events:4)
# DEBUG:ASP generator: Initializing clingo trace(147/2211) with length:4), Seed 2787043806
# ...
# DEBUG:ASP generator: Generating trace:15/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(15/17) with length:10), Seed 3751222129
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_5,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_10,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:16/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(16/17) with length:10), Seed 1177545640
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_0,3), trace(evt_val_10,4), trace(evt_val_5,5), trace(evt_val_0,6), trace(evt_val_1,7), trace(evt_val_0,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:17/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(17/17) with length:10), Seed 2043655164
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_6,4), trace(evt_val_2,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_1,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:3, Events: 13, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/3 with events:13)
# DEBUG:ASP generator: Initializing clingo trace(1/3) with length:13), Seed 2242105200
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,4), trace(evt_val_1,7), trace(evt_val_1,8), trace(evt_val_1,10), trace(evt_val_1,11), trace(evt_val_2,2), trace(evt_val_2,9), trace(evt_val_2,12), trace(evt_val_3,13), trace(evt_val_4,3), trace(evt_val_6,5), trace(evt_val_8,6)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/3 with events:13)
# DEBUG:ASP generator: Initializing clingo trace(2/3) with length:13), Seed 572292811
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,3), trace(evt_val_1,5), trace(evt_val_1,6), trace(evt_val_2,2), trace(evt_val_2,4), trace(evt_val_2,7), trace(evt_val_2,9), trace(evt_val_2,10), trace(evt_val_2,11), trace(evt_val_2,12), trace(evt_val_3,13), trace(evt_val_6,8)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/3 with events:13)
# DEBUG:ASP generator: Initializing clingo trace(3/3) with length:13), Seed 1510906991
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,3), trace(evt_val_2,5), trace(evt_val_2,10), trace(evt_val_2,11), trace(evt_val_2,12), trace(evt_val_3,13), trace(evt_val_5,7), trace(evt_val_5,9), trace(evt_val_6,8), trace(evt_val_7,6), trace(evt_val_10,2), trace(evt_val_12,4)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:17, Events: 9, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(1/17) with length:9), Seed 1673270886
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_10,5), trace(evt_val_1,6), trace(evt_val_1,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(2/17) with length:9), Seed 2475029726
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_1,4), trace(evt_val_2,5), trace(evt_val_2,6), trace(evt_val_1,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(3/17) with length:9), Seed 642241065
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_8,3), trace(evt_val_8,4), trace(evt_val_1,5), trace(evt_val_10,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:4/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(4/17) with length:9), Seed 3044971105
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_10,3), trace(evt_val_11,4), trace(evt_val_0,5), trace(evt_val_2,6), trace(evt_val_11,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:5/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(5/17) with length:9), Seed 1082285680
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_12,4), trace(evt_val_0,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:6/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(6/17) with length:9), Seed 2961351336
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_0,3), trace(evt_val_4,4), trace(evt_val_0,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:7/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(7/17) with length:9), Seed 3124245523
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_12,4), trace(evt_val_11,5), trace(evt_val_1,6), trace(evt_val_6,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:8/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(8/17) with length:9), Seed 2481756398
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_12,4), trace(evt_val_0,5), trace(evt_val_0,6), trace(evt_val_0,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:9/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(9/17) with length:9), Seed 2197849155
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_8,3), trace(evt_val_9,4), trace(evt_val_12,5), trace(evt_val_2,6), trace(evt_val_9,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:10/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(10/17) with length:9), Seed 3800021014
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_1,4), trace(evt_val_6,5), trace(evt_val_4,6), trace(evt_val_1,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:11/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(11/17) with length:9), Seed 2561774372
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_0,4), trace(evt_val_6,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:12/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(12/17) with length:9), Seed 809938664
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_0,3), trace(evt_val_4,4), trace(evt_val_0,5), trace(evt_val_7,6), trace(evt_val_12,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:13/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(13/17) with length:9), Seed 3833014411
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_10,3), trace(evt_val_0,4), trace(evt_val_2,5), trace(evt_val_11,6), trace(evt_val_6,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:14/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(14/17) with length:9), Seed 1266746113
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_0,3), trace(evt_val_10,4), trace(evt_val_0,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:15/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(15/17) with length:9), Seed 2982286681
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_5,4), trace(evt_val_0,5), trace(evt_val_2,6), trace(evt_val_12,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:16/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(16/17) with length:9), Seed 3033561095
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_7,3), trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_0,6), trace(evt_val_8,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:17/17 with events:9)
# DEBUG:ASP generator: Initializing clingo trace(17/17) with length:9), Seed 2696275863
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_7,4), trace(evt_val_0,5), trace(evt_val_0,6), trace(evt_val_4,7), trace(evt_val_2,8), trace(evt_val_3,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:5, Events: 12, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/5 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(1/5) with length:12), Seed 2590996997
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_10,5), trace(evt_val_12,6), trace(evt_val_1,7), trace(evt_val_2,8), trace(evt_val_2,9), trace(evt_val_4,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/5 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(2/5) with length:12), Seed 2444838646
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_2,5), trace(evt_val_1,6), trace(evt_val_1,7), trace(evt_val_10,8), trace(evt_val_9,9), trace(evt_val_2,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/5 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(3/5) with length:12), Seed 3646930576
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_0,3), trace(evt_val_1,4), trace(evt_val_0,5), trace(evt_val_0,6), trace(evt_val_8,7), trace(evt_val_4,8), trace(evt_val_0,9), trace(evt_val_0,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:4/5 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(4/5) with length:12), Seed 1656288893
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_8,4), trace(evt_val_2,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_4,8), trace(evt_val_11,9), trace(evt_val_1,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:5/5 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(5/5) with length:12), Seed 1506096876
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_5,3), trace(evt_val_1,4), trace(evt_val_0,5), trace(evt_val_4,6), trace(evt_val_0,7), trace(evt_val_12,8), trace(evt_val_0,9), trace(evt_val_7,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:1, Events: 14, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/1 with events:14)
# DEBUG:ASP generator: Initializing clingo trace(1/1) with length:14), Seed 806272612
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,5), trace(evt_val_1,7), trace(evt_val_1,8), trace(evt_val_1,9), trace(evt_val_2,2), trace(evt_val_2,4), trace(evt_val_2,11), trace(evt_val_2,13), trace(evt_val_3,14), trace(evt_val_4,6), trace(evt_val_5,10), trace(evt_val_8,12), trace(evt_val_10,3)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:3, Events: 11, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/3 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(1/3) with length:11), Seed 4113738180
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_11,4), trace(evt_val_4,5), trace(evt_val_1,6), trace(evt_val_11,7), trace(evt_val_2,8), trace(evt_val_1,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/3 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(2/3) with length:11), Seed 647902542
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_0,3), trace(evt_val_1,4), trace(evt_val_5,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_5,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/3 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(3/3) with length:11), Seed 1594298472
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_4,3), trace(evt_val_0,4), trace(evt_val_4,5), trace(evt_val_0,6), trace(evt_val_10,7), trace(evt_val_1,8), trace(evt_val_0,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:2, Events: 2, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/2 with events:2)
# DEBUG:ASP generator: Initializing clingo trace(1/2) with length:2), Seed 250701041
# DEBUG:ASP generator: Clingo Result: UNSAT
# DEBUG:ASP generator: Generating trace:2/2 with events:2)
# DEBUG:ASP generator: Initializing clingo trace(2/2) with length:2), Seed 1921446575
# DEBUG:ASP generator: Clingo Result: UNSAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:1, Events: 15, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/1 with events:15)
# DEBUG:ASP generator: Initializing clingo trace(1/1) with length:15), Seed 804669992
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,6), trace(evt_val_1,9), trace(evt_val_1,11), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_2,5), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_2,13), trace(evt_val_2,14), trace(evt_val_3,15), trace(evt_val_4,10), trace(evt_val_4,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator:Traces generated. Positive: 3662 Neg: 0. Parsing Trace results.
# DEBUG:ASP generator:Trace results parsed
# DEBUG:ASP generator:Generating Pm4py log
# WARNING:ASP generator:PM4PY log generated: 3662/3664 only.
# DEBUG:ASP generator:Pm4py generated but not saved yet
# exporting log, completed traces ::   0%|          | 0/3662 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/3662 [00:00<?, ?it/s]
# {'distribution_name': 'gamma', 'distribution_params': [{'value': 7664.858238723535}, {'value': 200319470.91884205}, {'value': 5.0}, {'value': 61493.0}]}

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = helpdesk.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = helpdesk.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
helpdesk.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
helpdesk.train_val_split()

# Augment the original data with filtered synthetic data
helpdesk.augment_new_variants()

# Save the augmented and original data
helpdesk.save_total_data('original')
helpdesk.save_total_data('augmented')
# Out:
# Number of common variants: 25
# Sorted common variants: [(('Assign seriousness', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 35, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.009557618787547788}), (('Assign seriousness', 'Take in charge ticket', 'Take in charge ticket', 'Require upgrade', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 1, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.00027307482250136535}), (('Assign seriousness', 'Take in charge ticket', 'Schedule intervention', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 3, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0008192244675040961}), (('Assign seriousness', 'Resolve ticket', 'Wait', 'Wait', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 1, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.00027307482250136535}), (('Assign seriousness', 'Resolve ticket', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 48, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.013107591480065538}), (('Assign seriousness', 'Take in charge ticket', 'Resolve SW anomaly', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 2, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0005461496450027307}), (('Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Wait', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 1, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.00027307482250136535}), (('Assign seriousness', 'Assign seriousness', 'Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 2, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0005461496450027307}), (('Assign seriousness', 'Wait', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 2, 'frequency_syn': 7, 'proportion_orig': 0.0005458515283842794, 'proportion_syn': 0.0019115237575095577}), (('Assign seriousness', 'Assign seriousness', 'Assign seriousness', 'Resolve ticket', 'Closed'), {'frequency_orig': 2, 'frequency_syn': 31, 'proportion_orig': 0.0005458515283842794, 'proportion_syn': 0.008465319497542327}), (('Assign seriousness', 'Assign seriousness', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 2, 'frequency_syn': 1, 'proportion_orig': 0.0005458515283842794, 'proportion_syn': 0.00027307482250136535}), (('Assign seriousness', 'Take in charge ticket', 'Require upgrade', 'Resolve ticket', 'Closed'), {'frequency_orig': 3, 'frequency_syn': 2, 'proportion_orig': 0.0008187772925764192, 'proportion_syn': 0.0005461496450027307}), (('Assign seriousness', 'Wait', 'Resolve ticket', 'Closed'), {'frequency_orig': 5, 'frequency_syn': 104, 'proportion_orig': 0.0013646288209606986, 'proportion_syn': 0.028399781540142}), (('Assign seriousness', 'Take in charge ticket', 'Wait', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 6, 'frequency_syn': 1, 'proportion_orig': 0.0016375545851528383, 'proportion_syn': 0.00027307482250136535}), (('Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 7, 'frequency_syn': 3, 'proportion_orig': 0.001910480349344978, 'proportion_syn': 0.0008192244675040961}), (('Assign seriousness', 'Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 13, 'frequency_syn': 4, 'proportion_orig': 0.0035480349344978166, 'proportion_syn': 0.0010922992900054614}), (('Assign seriousness', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 14, 'frequency_syn': 5, 'proportion_orig': 0.003820960698689956, 'proportion_syn': 0.001365374112506827}), (('Assign seriousness', 'Assign seriousness', 'Resolve ticket', 'Closed'), {'frequency_orig': 15, ...

# %% [markdown]
# ## Sepsis

# %%
# Initialize EventLogProcessor class for Sepsis 
sepsis = event_processor = EventLogProcessor("sepsis")

# Apply Train-Test Split
sepsis.train_test_split()

# Convert train data to an event log
sepsis.generate_train_log()

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
sepsis.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For Sepsis we define:
# * number of required mean values: 4
# * consider business hours: False
# * consider weekday: False

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = sepsis.get_syn_log_parameters()

# Simulate declarative process model
sepsis.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
sepsis.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = sepsis.generate_timedelta(1)

# Get case arrival distribution
inter_case_dist = sepsis.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = sepsis.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
sepsis.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=False, consider_day=False)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[3], line 2
#
#       1 # Get parameters for declarative process simulation
#
# ----> 2 min_events, max_events, num_of_cases, orig_prob = helpdesk.get_syn_log_parameters()
#
#       4 # Simulate declarative process model
#
#       5 helpdesk.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)
#
#
#
# NameError: name 'helpdesk' is not defined

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = sepsis.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = sepsis.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
sepsis.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
sepsis.train_val_split()

# Augment the original data with filtered synthetic data
sepsis.augment_new_variants()

# Save the augmented and original data
sepsis.save_total_data('original')
sepsis.save_total_data('augmented')

# %% [markdown]
# ## BPIC13C

# %%
# Initialize EventLogProcessor class for BPIC13C 
bpic13c = event_processor = EventLogProcessor("bpic13c")

# Apply Train-Test Split
bpic13c.train_test_split()

# Convert train data to an event log
bpic13c.generate_train_log()

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
bpic13c.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For BPIC13C we define:
# * number of required mean values: 4
# * consider business hours: True
# * consider weekday: True

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = bpic13c.get_syn_log_parameters()

# Simulate declarative process model
bpic13c.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
bpic13c.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = bpic13c.generate_timedelta(4)

# Get case arrival distribution
inter_case_dist = bpic13c.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = bpic13c.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
bpic13c.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=True, consider_day=True)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[3], line 2
#
#       1 # Get parameters for declarative process simulation
#
# ----> 2 min_events, max_events, num_of_cases, orig_prob = helpdesk.get_syn_log_parameters()
#
#       4 # Simulate declarative process model
#
#       5 helpdesk.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)
#
#
#
# NameError: name 'helpdesk' is not defined

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = bpic13c.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = bpic13c.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
bpic13c.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
bpic13c.train_val_split()

# Augment the original data with filtered synthetic data
bpic13c.augment_new_variants()

# Save the augmented and original data
bpic13c.save_total_data('original')
bpic13c.save_total_data('augmented')

# %% [markdown]
# ## BPIC15_1

# %%
# Initialize EventLogProcessor class for BPIC15_1 
bpic15_1 = event_processor = EventLogProcessor("bpic15_1")

# Apply Train-Test Split
bpic15_1.train_test_split()

# Convert train data to an event log
bpic15_1.generate_train_log()

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
bpic15_1.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For BPIC15_1 we define:
# * number of required mean values: 4
# * consider business hours: False
# * consider weekday: False

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = bpic15_1.get_syn_log_parameters()

# Simulate declarative process model
bpic15_1.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
bpic15_1.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = bpic15_1.generate_timedelta(4)

# Get case arrival distribution
inter_case_dist = bpic15_1.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = bpic15_1.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
bpic15_1.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=False, consider_day=False)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[3], line 2
#
#       1 # Get parameters for declarative process simulation
#
# ----> 2 min_events, max_events, num_of_cases, orig_prob = helpdesk.get_syn_log_parameters()
#
#       4 # Simulate declarative process model
#
#       5 helpdesk.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)
#
#
#
# NameError: name 'helpdesk' is not defined

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = bpic15_1.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = bpic15_1.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
bpic15_1.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
bpic15_1.train_val_split()

# Augment the original data with filtered synthetic data
bpic15_1.augment_new_variants()

# Save the augmented and original data
bpic15_1.save_total_data('original')
bpic15_1.save_total_data('augmented')
