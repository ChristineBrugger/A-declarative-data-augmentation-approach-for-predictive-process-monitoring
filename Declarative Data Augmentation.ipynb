# %%
# Import necessary script
from scripts.dda_functions import EventLogProcessor

# %% [markdown]
# # Declarative Data Augmentation
# We present our declarative data augmentation approach in this notebook. Every step that is necessary to generate synthetic data, which can then be used to augment the original data will be presented and explained here.

# %% [markdown]
# ## Helpdesk

# %%
# Initialize EventLogProcessor class for Helpdesk 
helpdesk = event_processor = EventLogProcessor("helpdesk")

# Apply Train-Test Split
helpdesk.train_test_split()

# Convert train data to an event log
helpdesk.generate_train_log()
# Out:
# exporting log, completed traces :: 100%|██████████| 3664/3664 [00:00<00:00, 8319.06it/s]

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
helpdesk.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)
# Out:
# parsing log, completed traces :: 100%|██████████| 3664/3664 [00:00<00:00, 6512.34it/s]
# Computing discovery ...
# Model activities:
# -----------------
# 0 Assign seriousness
# 1 Take in charge ticket
# 2 Resolve ticket
# 3 Closed
# 4 Insert ticket
# 5 Wait
# 6 Create SW anomaly
# 7 Require upgrade
# 8 Resolve SW anomaly
# 9 Schedule intervention
# 10 RESOLVED
# 11 INVALID
# 12 VERIFIED
#
#
# Model constraints:
# -----------------
# 0 Existence1[Resolve ticket] | |
# 1 Existence1[Closed] | |
# 2 Absence2[Closed] | |
# 3 Exactly1[Closed] | |
# 4 End[Closed] | |
# 5 Existence1[Assign seriousness] | |
# 6 Init[Assign seriousness] | |
# 7 Choice[Resolve ticket, Closed] | | |
# 8 Choice[Closed, Resolve ticket] | | |
# 9 Responded Existence[Resolve ticket, Closed] | | |
# 10 Responded Existence[Closed, Resolve ticket] | | |
# 11 Response[Resolve ticket, Closed] | | |
# 12 Precedence[Resolve ticket, Closed] | | |
# 13 Alternate Precedence[Resolve ticket, Closed] | | |
# 14 Chain Precedence[Resolve ticket, Closed] | | |
# 15 Not Response[Closed, Resolve ticket] | | |
# 16 Not Precedence[Closed, Resolve ticket] | | |
# 17 Not Chain Response[Closed, Resolve ticket] | | |
# 18 Not Chain Precedence[Closed, Resolve ticket] | | |
# 19 Choice[Resolve ticket, Assign seriousness] | | |
# 20 Choice[Assign seriousness, Resolve ticket] | | |
# 21 Responded Existence[Resolve ticket, Assign seriousness] | | |
# 22 Responded Existence[Assign seriousness, Resolve ticket] | | |
# 23 Response[Assign seriousness, Resolve ticket] | | |
# 24 Precedence[Assign seriousness, Resolve ticket] | | |
# 25 Not Response[Resolve ticket, Assign seriousness] | | |
# 26 Not Precedence[Resolve ticket, Assign seriousness] | | |
# 27 Not Chain Response[Resolve ticket, Assign seriousness] | | |
# 28 Not Chain Precedence[Resolve ticket, Assign seriousness] | | |
# 29 Choice[Closed, Assign seriousness] | | |
# 30 Choice[Assign seriousness, Closed] | | |
# 31 Responded Existence[Closed, Assign seriousness] | | |
# 32 Responded Existence[Assign seriousness, Closed] | | |
# 33 Response[Assign seriousness, Closed] | | |
# 34 Precedence[Assign seriousness, Closed] | | |
# 35 Alternate Precedence[Assign seriousness, Closed] | | |
# 36 Not Response[Closed, Assign seriousness] | | |
# 37 Not Precedence[Closed, Assign seriousness] | | |
# 38 Not Chain Response[Closed, Assign seriousness] | | |
# 39 Not Chain Response[Assign seriousness, Closed] | | |
# 40 Not Chain Precedence[Closed, Assign seriousness] | | |
# 41 Not Chain Precedence[Assign seriousness, Closed] | | |

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For Helpdesk we define:
# * number of required mean values: 1
# * consider business hours: True
# * consider weekday: True

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = helpdesk.get_syn_log_parameters()

# Simulate declarative process model
helpdesk.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
helpdesk.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = helpdesk.generate_timedelta(1)

# Get case arrival distribution
inter_case_dist = helpdesk.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = helpdesk.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
helpdesk.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=True, consider_day=True)
# Out:
# DEBUG:ASP generator:Distribution for traces uniform
# DEBUG:ASP generator:traces: 3664, events can have a trace min(2) max(15)
# INFO:ASP generator:Computing distribution
# DEBUG:Distributor:Distribution() uniform min_mu: 2 max_sigma: 15 num_traces: 3664 custom_prob: None
# DEBUG:Distributor:Uniform() probabilities: [Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14), Fraction(1, 14)]
# DEBUG:Distributor:Custom_dist() min_mu:2 max_sigma:15 num_traces:3664
# DEBUG:Distributor:Probabilities sum 1
# DEBUG:Distributor:Distribution result: [10  7  8 ... 13 15  7]
# INFO:ASP generator:Distribution result Counter({7: 287, 13: 281, 5: 273, 15: 273, 10: 271, 4: 269, 6: 267, 3: 266, 2: 261, 14: 253, 11: 247, 9: 246, 8: 245, 12: 225})
# DEBUG:ASP generator:Using custom traces length
# INFO:ASP generator:Computing distribution
# DEBUG:Distributor:Distribution() custom min_mu: 2 max_sigma: 15 num_traces: 3664 custom_prob: [0.0002729258, 0.0461244541, 0.5889737991, 0.1956877729, 0.0966157205, 0.0373908297, 0.0221069869, 0.0054585153, 0.0032751092, 0.0019104803, 0.0010917031, 0.0005458515, 0.0002729258, 0.000272925800000111]
# DEBUG:Distributor:Custom_dist() min_mu:2 max_sigma:15 num_traces:3664
# DEBUG:Distributor:Probabilities sum 1.0
# DEBUG:Distributor:Distribution result: [5 4 5 ... 4 5 6]
# INFO:ASP generator:Distribution result Counter({4: 2167, 5: 695, 6: 359, 3: 164, 7: 145, 8: 75, 9: 25, 10: 17, 11: 9, 13: 3, 12: 3, 14: 1, 15: 1})
# INFO:ASP generator:Computing distribution
# DEBUG:ASP generator:Generating traces
# DEBUG:ASP generator:Translate declare model to ASP
# DEBUG:ASP generator:Declare model translated to ASP. Total Facts 13
# DEBUG:ASP generator:ASP encoding generated
# DEBUG:ASP generator:Start generating traces: Counter({4: 2167, 5: 695, 6: 359, 3: 164, 7: 145, 8: 75, 9: 25, 10: 17, 11: 9, 13: 3, 12: 3, 14: 1, 15: 1})
# DEBUG:ASP generator: Total trace to generate and events: Traces:695, Events: 5, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(1/695) with length:5), Seed 3150516180
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(2/695) with length:5), Seed 1889868788
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(3/695) with length:5), Seed 865999568
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:4/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(4/695) with length:5), Seed 2656891206
#     Number of Events  Number of Cases
# 0                  2                1
# 1                  3              169
# 2                  4             2158
# 3                  5              717
# 4                  6              354
# 5                  7              137
# 6                  8               81
# 7                  9               20
# 8                 10               12
# 9                 11                7
# 10                12                4
# 11                13                2
# 12                14                1
# 13                15                1
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_7,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:5/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(5/695) with length:5), Seed 1469947857
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:6/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(6/695) with length:5), Seed 1369241278
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:7/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(7/695) with length:5), Seed 3124017647
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:8/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(8/695) with length:5), Seed 1956037268
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:9/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(9/695) with length:5), Seed 1584988407
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:10/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(10/695) with length:5), Seed 3250626032
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:11/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(11/695) with length:5), Seed 526613205
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:12/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(12/695) with length:5), Seed 3929570274
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:13/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(13/695) with length:5), Seed 2067486682
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:14/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(14/695) with length:5), Seed 512696005
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:15/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(15/695) with length:5), Seed 1439705737
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:16/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(16/695) with length:5), Seed 2810090178
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:17/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(17/695) with length:5), Seed 2202643567
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:18/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(18/695) with length:5), Seed 3978638061
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_11,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:19/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(19/695) with length:5), Seed 3397800335
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_7,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:20/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(20/695) with length:5), Seed 2560984037
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:21/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(21/695) with length:5), Seed 3884027687
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:22/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(22/695) with length:5), Seed 2654810275
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:23/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(23/695) with length:5), Seed 862846798
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:24/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(24/695) with length:5), Seed 1638505087
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:25/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(25/695) with length:5), Seed 2264300539
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:26/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(26/695) with length:5), Seed 709044799
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:27/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(27/695) with length:5), Seed 3974066584
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:28/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(28/695) with length:5), Seed 1727838721
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:29/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(29/695) with length:5), Seed 1363781050
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:30/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(30/695) with length:5), Seed 2481036296
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:31/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(31/695) with length:5), Seed 2646958924
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:32/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(32/695) with length:5), Seed 3889142111
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:33/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(33/695) with length:5), Seed 3980883263
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:34/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(34/695) with length:5), Seed 2118497391
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_10,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:35/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(35/695) with length:5), Seed 1998841038
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:36/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(36/695) with length:5), Seed 610914869
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:37/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(37/695) with length:5), Seed 4001862395
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_10,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:38/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(38/695) with length:5), Seed 2829269304
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_11,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:39/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(39/695) with length:5), Seed 1667012443
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:40/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(40/695) with length:5), Seed 895873735
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:41/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(41/695) with length:5), Seed 468713815
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:42/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(42/695) with length:5), Seed 3791985419
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:43/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(43/695) with length:5), Seed 2628457497
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:44/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(44/695) with length:5), Seed 3176293081
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:45/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(45/695) with length:5), Seed 2311884449
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:46/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(46/695) with length:5), Seed 489596668
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:47/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(47/695) with length:5), Seed 3620106575
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:48/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(48/695) with length:5), Seed 3440987958
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:49/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(49/695) with length:5), Seed 2386610453
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:50/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(50/695) with length:5), Seed 1022264722
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_11,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:51/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(51/695) with length:5), Seed 1224963135
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_10,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:52/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(52/695) with length:5), Seed 2119685317
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:53/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(53/695) with length:5), Seed 3682727179
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:54/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(54/695) with length:5), Seed 1741927852
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:55/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(55/695) with length:5), Seed 58685653
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:56/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(56/695) with length:5), Seed 2387139464
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_7,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:57/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(57/695) with length:5), Seed 841586705
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:58/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(58/695) with length:5), Seed 3959185903
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:59/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(59/695) with length:5), Seed 3270174906
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:60/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(60/695) with length:5), Seed 2751224345
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:61/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(61/695) with length:5), Seed 2782490781
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:62/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(62/695) with length:5), Seed 2502729921
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:63/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(63/695) with length:5), Seed 3185277399
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:64/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(64/695) with length:5), Seed 1544258382
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:65/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(65/695) with length:5), Seed 1265074185
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:66/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(66/695) with length:5), Seed 400909847
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:67/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(67/695) with length:5), Seed 3742075678
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:68/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(68/695) with length:5), Seed 1948669678
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:69/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(69/695) with length:5), Seed 1291257186
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:70/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(70/695) with length:5), Seed 856294716
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:71/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(71/695) with length:5), Seed 1910569908
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:72/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(72/695) with length:5), Seed 1168691047
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:73/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(73/695) with length:5), Seed 292428729
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:74/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(74/695) with length:5), Seed 853917548
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:75/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(75/695) with length:5), Seed 785706055
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:76/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(76/695) with length:5), Seed 1987641784
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:77/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(77/695) with length:5), Seed 1275043986
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_7,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:78/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(78/695) with length:5), Seed 4084098966
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:79/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(79/695) with length:5), Seed 3024942823
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:80/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(80/695) with length:5), Seed 2440142080
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:81/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(81/695) with length:5), Seed 1290508384
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:82/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(82/695) with length:5), Seed 2172909015
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:83/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(83/695) with length:5), Seed 1391272963
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:84/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(84/695) with length:5), Seed 2903382945
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:85/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(85/695) with length:5), Seed 2369868366
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:86/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(86/695) with length:5), Seed 520373143
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_7,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:87/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(87/695) with length:5), Seed 3894961608
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_9,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:88/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(88/695) with length:5), Seed 2214330611
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:89/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(89/695) with length:5), Seed 4128690005
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:90/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(90/695) with length:5), Seed 3334423323
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:91/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(91/695) with length:5), Seed 3851568608
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:92/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(92/695) with length:5), Seed 2463467290
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:93/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(93/695) with length:5), Seed 4282232105
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:94/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(94/695) with length:5), Seed 3271691052
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_11,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:95/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(95/695) with length:5), Seed 183607009
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:96/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(96/695) with length:5), Seed 1590872245
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:97/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(97/695) with length:5), Seed 3845257871
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:98/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(98/695) with length:5), Seed 3554530789
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:99/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(99/695) with length:5), Seed 3367976700
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:100/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(100/695) with length:5), Seed 2810643958
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:101/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(101/695) with length:5), Seed 3279717126
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:102/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(102/695) with length:5), Seed 1621301715
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:103/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(103/695) with length:5), Seed 203765151
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:104/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(104/695) with length:5), Seed 3597796576
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:105/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(105/695) with length:5), Seed 3802165975
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:106/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(106/695) with length:5), Seed 3080684886
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_5,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:107/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(107/695) with length:5), Seed 2616472891
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:108/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(108/695) with length:5), Seed 4085148922
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:109/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(109/695) with length:5), Seed 4147660737
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:110/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(110/695) with length:5), Seed 263695525
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:111/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(111/695) with length:5), Seed 512378218
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:112/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(112/695) with length:5), Seed 566662272
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:113/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(113/695) with length:5), Seed 1571433824
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:114/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(114/695) with length:5), Seed 1966658630
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:115/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(115/695) with length:5), Seed 3754420575
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:116/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(116/695) with length:5), Seed 943763630
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_7,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:117/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(117/695) with length:5), Seed 2317176734
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:118/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(118/695) with length:5), Seed 334333496
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_10,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:119/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(119/695) with length:5), Seed 594027098
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:120/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(120/695) with length:5), Seed 492447547
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:121/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(121/695) with length:5), Seed 1587620201
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_7,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:122/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(122/695) with length:5), Seed 3134020813
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:123/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(123/695) with length:5), Seed 3359610255
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_11,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:124/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(124/695) with length:5), Seed 2273147866
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_10,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:125/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(125/695) with length:5), Seed 2690061372
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:126/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(126/695) with length:5), Seed 43491741
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:127/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(127/695) with length:5), Seed 3790939338
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:128/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(128/695) with length:5), Seed 786120326
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_11,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:129/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(129/695) with length:5), Seed 1993361509
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:130/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(130/695) with length:5), Seed 2976464397
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_8,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:131/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(131/695) with length:5), Seed 3109056278
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:132/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(132/695) with length:5), Seed 2387705122
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:133/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(133/695) with length:5), Seed 1192205600
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:134/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(134/695) with length:5), Seed 104375024
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_6,2), trace(evt_val_6,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:135/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(135/695) with length:5), Seed 2544969977
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:136/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(136/695) with length:5), Seed 1611584518
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_9,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:137/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(137/695) with length:5), Seed 1207179591
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:138/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(138/695) with length:5), Seed 3590037993
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_5,2), trace(evt_val_4,3), trace(evt_val_2,4), trace(evt_val_3,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:139/695 with events:5)
# DEBUG:ASP generator: Initializing clingo trace(139/695) with length:5), Seed 336655794
# ...
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(2/17) with length:10), Seed 2740722930
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_6,3), trace(evt_val_10,4), trace(evt_val_2,5), trace(evt_val_7,6), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(3/17) with length:10), Seed 3588437004
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_5,4), trace(evt_val_1,5), trace(evt_val_1,6), trace(evt_val_1,7), trace(evt_val_11,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:4/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(4/17) with length:10), Seed 2153406375
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_6,5), trace(evt_val_1,6), trace(evt_val_10,7), trace(evt_val_5,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:5/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(5/17) with length:10), Seed 2507067633
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_0,4), trace(evt_val_4,5), trace(evt_val_4,6), trace(evt_val_11,7), trace(evt_val_2,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:6/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(6/17) with length:10), Seed 3958853843
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_10,3), trace(evt_val_6,4), trace(evt_val_12,5), trace(evt_val_9,6), trace(evt_val_0,7), trace(evt_val_1,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:7/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(7/17) with length:10), Seed 2283395389
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_1,3), trace(evt_val_2,4), trace(evt_val_2,5), trace(evt_val_5,6), trace(evt_val_1,7), trace(evt_val_1,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:8/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(8/17) with length:10), Seed 3589982217
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_6,4), trace(evt_val_8,5), trace(evt_val_2,6), trace(evt_val_11,7), trace(evt_val_6,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:9/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(9/17) with length:10), Seed 1997014584
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_7,5), trace(evt_val_2,6), trace(evt_val_2,7), trace(evt_val_11,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:10/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(10/17) with length:10), Seed 279676144
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_1,3), trace(evt_val_6,4), trace(evt_val_4,5), trace(evt_val_2,6), trace(evt_val_1,7), trace(evt_val_10,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:11/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(11/17) with length:10), Seed 949711006
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_2,3), trace(evt_val_6,4), trace(evt_val_4,5), trace(evt_val_4,6), trace(evt_val_1,7), trace(evt_val_2,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:12/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(12/17) with length:10), Seed 704034080
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_1,3), trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_1,6), trace(evt_val_6,7), trace(evt_val_0,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:13/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(13/17) with length:10), Seed 2817693838
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_0,6), trace(evt_val_8,7), trace(evt_val_5,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:14/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(14/17) with length:10), Seed 357488394
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_9,3), trace(evt_val_8,4), trace(evt_val_0,5), trace(evt_val_9,6), trace(evt_val_2,7), trace(evt_val_1,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:15/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(15/17) with length:10), Seed 2466627156
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_4,3), trace(evt_val_0,4), trace(evt_val_4,5), trace(evt_val_12,6), trace(evt_val_0,7), trace(evt_val_12,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:16/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(16/17) with length:10), Seed 330682080
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_5,3), trace(evt_val_0,4), trace(evt_val_1,5), trace(evt_val_1,6), trace(evt_val_7,7), trace(evt_val_6,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:17/17 with events:10)
# DEBUG:ASP generator: Initializing clingo trace(17/17) with length:10), Seed 3698692633
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_0,3), trace(evt_val_7,4), trace(evt_val_0,5), trace(evt_val_4,6), trace(evt_val_2,7), trace(evt_val_5,8), trace(evt_val_2,9), trace(evt_val_3,10)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:9, Events: 11, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(1/9) with length:11), Seed 2144981802
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_4,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_4,5), trace(evt_val_1,6), trace(evt_val_11,7), trace(evt_val_2,8), trace(evt_val_12,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(2/9) with length:11), Seed 4092769086
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_4,5), trace(evt_val_1,6), trace(evt_val_10,7), trace(evt_val_1,8), trace(evt_val_2,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(3/9) with length:11), Seed 310758183
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_8,2), trace(evt_val_7,3), trace(evt_val_0,4), trace(evt_val_12,5), trace(evt_val_0,6), trace(evt_val_1,7), trace(evt_val_7,8), trace(evt_val_10,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:4/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(4/9) with length:11), Seed 2773325396
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_12,2), trace(evt_val_0,3), trace(evt_val_5,4), trace(evt_val_0,5), trace(evt_val_2,6), trace(evt_val_6,7), trace(evt_val_1,8), trace(evt_val_2,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:5/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(5/9) with length:11), Seed 2573128181
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_7,2), trace(evt_val_4,3), trace(evt_val_10,4), trace(evt_val_0,5), trace(evt_val_12,6), trace(evt_val_10,7), trace(evt_val_0,8), trace(evt_val_2,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:6/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(6/9) with length:11), Seed 1253729357
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_4,5), trace(evt_val_5,6), trace(evt_val_6,7), trace(evt_val_5,8), trace(evt_val_4,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:7/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(7/9) with length:11), Seed 3566543403
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_11,2), trace(evt_val_0,3), trace(evt_val_2,4), trace(evt_val_2,5), trace(evt_val_10,6), trace(evt_val_12,7), trace(evt_val_6,8), trace(evt_val_11,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:8/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(8/9) with length:11), Seed 3690168159
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_0,3), trace(evt_val_0,4), trace(evt_val_0,5), trace(evt_val_2,6), trace(evt_val_7,7), trace(evt_val_6,8), trace(evt_val_1,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:9/9 with events:11)
# DEBUG:ASP generator: Initializing clingo trace(9/9) with length:11), Seed 903504348
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_10,3), trace(evt_val_4,4), trace(evt_val_9,5), trace(evt_val_2,6), trace(evt_val_10,7), trace(evt_val_2,8), trace(evt_val_5,9), trace(evt_val_2,10), trace(evt_val_3,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:3, Events: 13, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/3 with events:13)
# DEBUG:ASP generator: Initializing clingo trace(1/3) with length:13), Seed 2481639263
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_1,7), trace(evt_val_1,11), trace(evt_val_2,4), trace(evt_val_2,5), trace(evt_val_2,6), trace(evt_val_2,8), trace(evt_val_2,12), trace(evt_val_3,13), trace(evt_val_5,10), trace(evt_val_8,3), trace(evt_val_9,9)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/3 with events:13)
# DEBUG:ASP generator: Initializing clingo trace(2/3) with length:13), Seed 2892474004
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,5), trace(evt_val_1,8), trace(evt_val_1,10), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,12), trace(evt_val_3,13), trace(evt_val_5,9), trace(evt_val_7,11), trace(evt_val_10,4), trace(evt_val_12,6), trace(evt_val_12,7)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/3 with events:13)
# DEBUG:ASP generator: Initializing clingo trace(3/3) with length:13), Seed 615021717
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,3), trace(evt_val_1,5), trace(evt_val_1,6), trace(evt_val_1,11), trace(evt_val_2,2), trace(evt_val_2,4), trace(evt_val_2,7), trace(evt_val_2,10), trace(evt_val_2,12), trace(evt_val_3,13), trace(evt_val_4,9), trace(evt_val_6,8)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:1, Events: 14, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/1 with events:14)
# DEBUG:ASP generator: Initializing clingo trace(1/1) with length:14), Seed 1182842925
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,8), trace(evt_val_1,12), trace(evt_val_2,2), trace(evt_val_2,3), trace(evt_val_2,4), trace(evt_val_2,6), trace(evt_val_2,9), trace(evt_val_2,13), trace(evt_val_3,14), trace(evt_val_4,10), trace(evt_val_7,7), trace(evt_val_9,5), trace(evt_val_12,11)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:3, Events: 12, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/3 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(1/3) with length:12), Seed 2197494113
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_0,3), trace(evt_val_7,4), trace(evt_val_2,5), trace(evt_val_6,6), trace(evt_val_7,7), trace(evt_val_2,8), trace(evt_val_12,9), trace(evt_val_2,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:2/3 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(2/3) with length:12), Seed 2906486572
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_2,2), trace(evt_val_12,3), trace(evt_val_8,4), trace(evt_val_1,5), trace(evt_val_4,6), trace(evt_val_1,7), trace(evt_val_4,8), trace(evt_val_9,9), trace(evt_val_5,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Generating trace:3/3 with events:12)
# DEBUG:ASP generator: Initializing clingo trace(3/3) with length:12), Seed 4099017115
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_0,2), trace(evt_val_4,3), trace(evt_val_12,4), trace(evt_val_12,5), trace(evt_val_12,6), trace(evt_val_5,7), trace(evt_val_11,8), trace(evt_val_0,9), trace(evt_val_9,10), trace(evt_val_2,11), trace(evt_val_3,12)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator: Total trace to generate and events: Traces:1, Events: 15, RandFrequency: 0.9
# DEBUG:ASP generator: Generating trace:1/1 with events:15)
# DEBUG:ASP generator: Initializing clingo trace(1/1) with length:15), Seed 2461248829
# DEBUG:ASP generator: Traces generated :[trace(evt_val_0,1), trace(evt_val_1,2), trace(evt_val_1,10), trace(evt_val_2,4), trace(evt_val_2,7), trace(evt_val_2,8), trace(evt_val_2,11), trace(evt_val_2,13), trace(evt_val_2,14), trace(evt_val_3,15), trace(evt_val_5,3), trace(evt_val_6,9), trace(evt_val_7,6), trace(evt_val_9,12), trace(evt_val_12,5)]
# DEBUG:ASP generator: Clingo Result: SAT
# DEBUG:ASP generator:Traces generated. Positive: 3664 Neg: 0. Parsing Trace results.
# DEBUG:ASP generator:Trace results parsed
# DEBUG:ASP generator:Generating Pm4py log
# DEBUG:ASP generator:Pm4py generated but not saved yet
# exporting log, completed traces :: 100%|██████████| 3664/3664 [00:00<00:00, 4224.35it/s]
# parsing log, completed traces :: 100%|██████████| 3664/3664 [00:01<00:00, 2965.19it/s]
# {'distribution_name': 'gamma', 'distribution_params': [{'value': 7664.858238723535}, {'value': 200319470.91884205}, {'value': 5.0}, {'value': 61493.0}]}

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = helpdesk.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = helpdesk.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
helpdesk.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
helpdesk.train_val_split()

# Augment the original data with filtered synthetic data
helpdesk.augment_new_variants()

# Save the augmented and original data
helpdesk.save_total_data('original')
helpdesk.save_total_data('augmented')
# Out:
# Number of common variants: 29
# Sorted common variants: [(('Assign seriousness', 'Resolve ticket', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 43, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.011735807860262008}), (('Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Wait', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 1, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0002729257641921397}), (('Assign seriousness', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 19, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.005185589519650655}), (('Assign seriousness', 'Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 2, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0005458515283842794}), (('Assign seriousness', 'Wait', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 1, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0002729257641921397}), (('Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 1, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0002729257641921397}), (('Assign seriousness', 'Take in charge ticket', 'Schedule intervention', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 6, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0016375545851528383}), (('Assign seriousness', 'Take in charge ticket', 'Resolve SW anomaly', 'Resolve ticket', 'Closed'), {'frequency_orig': 1, 'frequency_syn': 3, 'proportion_orig': 0.0002729257641921397, 'proportion_syn': 0.0008187772925764192}), (('Assign seriousness', 'Assign seriousness', 'Assign seriousness', 'Resolve ticket', 'Closed'), {'frequency_orig': 2, 'frequency_syn': 33, 'proportion_orig': 0.0005458515283842794, 'proportion_syn': 0.009006550218340612}), (('Assign seriousness', 'Assign seriousness', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 2, 'frequency_syn': 1, 'proportion_orig': 0.0005458515283842794, 'proportion_syn': 0.0002729257641921397}), (('Assign seriousness', 'Wait', 'Wait', 'Resolve ticket', 'Closed'), {'frequency_orig': 2, 'frequency_syn': 4, 'proportion_orig': 0.0005458515283842794, 'proportion_syn': 0.001091703056768559}), (('Assign seriousness', 'Wait', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 2, 'frequency_syn': 6, 'proportion_orig': 0.0005458515283842794, 'proportion_syn': 0.0016375545851528383}), (('Assign seriousness', 'Take in charge ticket', 'Require upgrade', 'Resolve ticket', 'Closed'), {'frequency_orig': 3, 'frequency_syn': 2, 'proportion_orig': 0.0008187772925764192, 'proportion_syn': 0.0005458515283842794}), (('Assign seriousness', 'Wait', 'Resolve ticket', 'Closed'), {'frequency_orig': 5, 'frequency_syn': 100, 'proportion_orig': 0.0013646288209606986, 'proportion_syn': 0.027292576419213975}), (('Assign seriousness', 'Take in charge ticket', 'Wait', 'Resolve ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 6, 'frequency_syn': 1, 'proportion_orig': 0.0016375545851528383, 'proportion_syn': 0.0002729257641921397}), (('Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Wait', 'Resolve ticket', 'Closed'), {'frequency_orig': 11, 'frequency_syn': 2, 'proportion_orig': 0.003002183406113537, 'proportion_syn': 0.0005458515283842794}), (('Assign seriousness', 'Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig': 13, 'frequency_syn': 1, 'proportion_orig': 0.0035480349344978166, 'proportion_syn': 0.0002729257641921397}), (('Assign seriousness', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Closed'), {'frequency_orig':  ...

# %% [markdown]
# ## Sepsis

# %%
# Initialize EventLogProcessor class for Sepsis 
sepsis = event_processor = EventLogProcessor("sepsis")

# Apply Train-Test Split
sepsis.train_test_split()

# Convert train data to an event log
sepsis.generate_train_log()

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
sepsis.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For Sepsis we define:
# * number of required mean values: 4
# * consider business hours: False
# * consider weekday: False

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = sepsis.get_syn_log_parameters()

# Simulate declarative process model
sepsis.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
sepsis.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = sepsis.generate_timedelta(1)

# Get case arrival distribution
inter_case_dist = sepsis.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = sepsis.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
sepsis.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=False, consider_day=False)

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = sepsis.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = sepsis.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
sepsis.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
sepsis.train_val_split()

# Augment the original data with filtered synthetic data
sepsis.augment_new_variants()

# Save the augmented and original data
sepsis.save_total_data('original')
sepsis.save_total_data('augmented')

# %% [markdown]
# ## BPIC13C

# %%
# Initialize EventLogProcessor class for BPIC13C 
bpic13c = event_processor = EventLogProcessor("bpic13c")

# Apply Train-Test Split
bpic13c.train_test_split()

# Convert train data to an event log
bpic13c.generate_train_log()

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
bpic13c.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For BPIC13C we define:
# * number of required mean values: 4
# * consider business hours: True
# * consider weekday: True

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = bpic13c.get_syn_log_parameters()

# Simulate declarative process model
bpic13c.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
bpic13c.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = bpic13c.generate_timedelta(4)

# Get case arrival distribution
inter_case_dist = bpic13c.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = bpic13c.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
bpic13c.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=True, consider_day=True)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[3], line 2
#
#       1 # Get parameters for declarative process simulation
#
# ----> 2 min_events, max_events, num_of_cases, orig_prob = helpdesk.get_syn_log_parameters()
#
#       4 # Simulate declarative process model
#
#       5 helpdesk.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)
#
#
#
# NameError: name 'helpdesk' is not defined

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = bpic13c.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = bpic13c.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
bpic13c.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
bpic13c.train_val_split()

# Augment the original data with filtered synthetic data
bpic13c.augment_new_variants()

# Save the augmented and original data
bpic13c.save_total_data('original')
bpic13c.save_total_data('augmented')

# %% [markdown]
# ## BPIC15_1

# %%
# Initialize EventLogProcessor class for BPIC15_1 
bpic15_1 = event_processor = EventLogProcessor("bpic15_1")

# Apply Train-Test Split
bpic15_1.train_test_split()

# Convert train data to an event log
bpic15_1.generate_train_log()

# %% [markdown]
# As there are many possible paramter combinations, we now need to define the specific parameter settings for the declarative process discovery. In our thesis we provide the results for the three different combinations:
#
# * consider_vacuity = False, min_support = 0.8, itemset_support = 0.8, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 2
# * consider_vacuity = True, min_support = 0.95, itemset_support = 0.95, max_declare_cardinality = 3
#
# In this notebook the user has to define on its own for which parameters the process should be discovered.

# %%
bpic15_1.declare_discovery(consider_vacuity=True, min_support=0.95, itemsets_support=0.95, max_declare_cardinality=2)

# %% [markdown]
# After the declarative process discovery we now need to define the parameters for the process simulation, as well as for the synthetic timestamp generation. Thereby it is important to define the required number of mean values for the time_delta as well as if the business hours and weekday should be considered at the timestamp generation.
#
# For BPIC15_1 we define:
# * number of required mean values: 4
# * consider business hours: False
# * consider weekday: False

# %%
# Get parameters for declarative process simulation
min_events, max_events, num_of_cases, orig_prob = bpic15_1.get_syn_log_parameters()

# Simulate declarative process model
bpic15_1.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)

# Convert the obtained synthetic log into an DataFrame for further use
bpic15_1.convert_syn_log_to_df()

# Apply synthetic timestamp generation
# Generate timedelta based on the required number of mean values
time_delta = bpic15_1.generate_timedelta(4)

# Get case arrival distribution
inter_case_dist = bpic15_1.get_inter_case_dist()

# Generate the first timestamps of each case
df_syn = bpic15_1.generate_first_timestamps(inter_case_dist=inter_case_dist)

# Generate remaining timestamps and define if business hours and weekday should be considered
bpic15_1.generate_timestamps(df_syn=df_syn, time_delta=time_delta, consider_hour=False, consider_day=False)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[3], line 2
#
#       1 # Get parameters for declarative process simulation
#
# ----> 2 min_events, max_events, num_of_cases, orig_prob = helpdesk.get_syn_log_parameters()
#
#       4 # Simulate declarative process model
#
#       5 helpdesk.generate_syn_log(num_of_cases=num_of_cases, num_min_events=min_events, num_max_events=max_events, orig_prob=orig_prob)
#
#
#
# NameError: name 'helpdesk' is not defined

# %% [markdown]
# The next step is to compute the common variants (variants that occur in the orginal and the synthetic data) and augment the original data. Therefore we need to define if common variants should not be augmented and based on what information they should be excluded.
# * *orig_proportion*: based on the proportion of the variant in the original data
# * *common_ratio*: defined percentage of the common variants will be excluded from the augmentation process

# %%
# Compute common variants
common_variants = bpic15_1.get_most_frequent_common_variants()

# Define if common variants should be removed
variants_to_remove = bpic15_1.common_variants_to_remove(common_variants=common_variants, method='orig_proportion', threshold=0.5)

# Save filtered variants
bpic15_1.save_filtered_variants(most_frequent_common_variants=variants_to_remove)

# Apply Train-Validation Split
bpic15_1.train_val_split()

# Augment the original data with filtered synthetic data
bpic15_1.augment_new_variants()

# Save the augmented and original data
bpic15_1.save_total_data('original')
bpic15_1.save_total_data('augmented')
