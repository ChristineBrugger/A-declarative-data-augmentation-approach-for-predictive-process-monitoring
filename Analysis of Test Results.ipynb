# %%
# Import necessary functions
from scripts.utils_analysis import *

# %% [markdown]
# # Analysis of Test Results
# In this notebook we provide the code and figures of the class-wise accuracy analysis of our prediction results. We will just analyze the best performing approaches, which we indicated in our thesis.

# %% [markdown]
# ## Helpdesk

# %% [markdown]
# ### Tax

# %%
# Load prediction Results
tax_base_hd = pd.read_csv('tax\\code\\results\\raw_helpdesk_baseline.txt', sep=';')
tax_orig_hd = pd.read_csv('tax\\code\\results\\raw_helpdesk_orig.txt', sep=';')
tax_dda_hd = pd.read_csv('tax\\code\\results\\raw_helpdesk_cvT_0.95_0.95_dc3_augm.txt', sep=';')

# Plot class-wise accuracy for Tax
plot_class_accuracy(tax_orig_hd, tax_dda_hd, tax_base_hd, 'Helpdesk by Tax')

# %% [markdown]
# ### Mauro

# %%
# Load data
nnpm_base_hd = pd.read_csv('nnpm\\results\\raw_helpdesk_baseline.txt', sep=';')
nnpm_orig_hd = pd.read_csv('nnpm\\results\\raw_helpdesk_orig.txt', sep=';')
nnpm_dda_hd = pd.read_csv('nnpm\\results\\raw_helpdesk_cvT_0.95_0.95_dc3_augm.txt', sep=';')

# Map activity categorization to the one of tax
nnpm_orig_hd = map_categorization(df_base=tax_orig_hd, df_adjust=nnpm_orig_hd)
nnpm_dda_hd = map_categorization(df_base=tax_orig_hd, df_adjust=nnpm_dda_hd)
nnpm_base_hd = map_categorization(df_base=tax_orig_hd, df_adjust=nnpm_base_hd)

# Plot class-wise accuracy for mauro
plot_class_accuracy(nnpm_orig_hd, nnpm_dda_hd, nnpm_base_hd, 'Helpdesk by Mauro')

# %% [markdown]
# ### Bukhsh

# %%
# Load data
pt_base_hd = pd.read_csv('processtransformer\\results\\helpdesk_baseline.csv\\results_raw_results.csv')
pt_orig_hd = pd.read_csv('processtransformer\\results\\helpdesk_orig.csv\\results_raw_results.csv')
pt_dda_hd = pd.read_csv('processtransformer\\results\\helpdesk_cvT_0.95_0.95_dc3_augm.csv\\results_raw_results.csv')

# Map activity categorization to the one of tax
pt_orig_hd = map_categorization(df_base=tax_orig_hd, df_adjust=pt_orig_hd)
pt_dda_hd = map_categorization(df_base=tax_orig_hd, df_adjust=pt_dda_hd)
pt_base_hd = map_categorization(df_base=tax_orig_hd, df_adjust=pt_base_hd)

# Plot class-wise accuracy for mauro
plot_class_accuracy(pt_orig_hd, pt_dda_hd, pt_base_hd, 'Helpdesk by Bukhsh')

# %% [markdown]
# ## Sepsis

# %% [markdown]
# ### Tax

# %%
# Load data
tax_base_sep = pd.read_csv('tax\\code\\results\\raw_sepsis_baseline.txt', sep=';')
tax_orig_sep = pd.read_csv('tax\\code\\results\\raw_sepsis_orig.txt', sep=';')
tax_dda_sep = pd.read_csv('tax\\code\\results\\raw_sepsis_cvT_0.95_0.95_dc3_augm.txt', sep=';')

# Plot class-wise accuracy
plot_class_accuracy(tax_orig_sep, tax_dda_sep, tax_base_sep, 'Sepsis by Tax')

# %% [markdown]
# ### Mauro

# %%
# Load data
nnpm_base_sep = pd.read_csv('nnpm\\results\\raw_sepsis_baseline.txt', sep=';')
nnpm_orig_sep = pd.read_csv('nnpm\\results\\raw_sepsis_orig.txt', sep=';')
nnpm_dda_sep = pd.read_csv('nnpm\\results\\raw_sepsis_cvF_0.8_0.8_dc2_augm.txt', sep=';')

# Map activity categorization to the one of tax
nnpm_orig_sep = map_categorization(df_base=tax_orig_sep, df_adjust=nnpm_orig_sep)
nnpm_dda_sep = map_categorization(df_base=tax_orig_sep, df_adjust=nnpm_dda_sep)
nnpm_base_sep = map_categorization(df_base=tax_orig_sep, df_adjust=nnpm_base_sep)

# Plot class-wise accuracy
plot_class_accuracy(nnpm_orig_sep, nnpm_dda_sep, nnpm_base_sep, 'Sepsis by Mauro')

# %% [markdown]
# ### Bukhsh

# %%
# Load data
pt_base_sep = pd.read_csv('processtransformer\\results\\sepsis_baseline.csv\\results_raw_results.csv')
pt_orig_sep = pd.read_csv('processtransformer\\results\\sepsis_orig.csv\\results_raw_results.csv')
pt_dda_sep = pd.read_csv('processtransformer\\results\\sepsis_cvT_0.95_0.95_dc2_augm.csv\\results_raw_results.csv')

# Map activity categorization to the one of tax
pt_orig_sep = map_categorization(df_base=tax_orig_sep, df_adjust=pt_orig_sep)
pt_dda_sep = map_categorization(df_base=tax_orig_sep, df_adjust=pt_dda_sep)
pt_base_sep = map_categorization(df_base=tax_orig_sep, df_adjust=pt_base_sep)

# Plot class-wise accuracy
plot_class_accuracy(pt_orig_sep, pt_dda_sep, pt_base_sep, 'Sepsis by Bukhsh')

# %% [markdown]
# ## BPIC13C

# %% [markdown]
# ### Tax

# %%
# Load data
tax_base_bpic13c = pd.read_csv('tax\\code\\results\\raw_bpic13c_baseline.txt', sep=';')
tax_orig_bpic13c = pd.read_csv('tax\\code\\results\\raw_bpic13c_orig.txt', sep=';')
tax_dda_bpic13c = pd.read_csv('tax\\code\\results\\raw_bpic13c_cvT_0.95_0.95_dc3_augm.txt', sep=';')

# Plot class-wise accuracy
plot_class_accuracy(tax_orig_bpic13c, tax_dda_bpic13c, tax_base_bpic13c, 'BPIC13C by Tax')

# %% [markdown]
# ### Mauro

# %%
# Load data
nnpm_base_bpic13c = pd.read_csv('nnpm\\results\\raw_bpic13c_baseline.txt', sep=';')
nnpm_orig_bpic13c = pd.read_csv('nnpm\\results\\raw_bpic13c_orig.txt', sep=';')
nnpm_dda_bpic13c= pd.read_csv('nnpm\\results\\raw_bpic13c_cvT_0.95_0.95_dc2_augm.txt', sep=';')

# Map activity categorization to the one of tax
nnpm_orig_bpic13c = map_categorization(df_base=tax_orig_bpic13c, df_adjust=nnpm_orig_bpic13c)
nnpm_dda_bpic13c = map_categorization(df_base=tax_orig_bpic13c, df_adjust=nnpm_dda_bpic13c)
nnpm_base_bpic13c = map_categorization(df_base=tax_orig_bpic13c, df_adjust=nnpm_base_bpic13c)

# Plot class-wise accuracy
plot_class_accuracy(nnpm_orig_bpic13c, nnpm_dda_bpic13c, nnpm_base_bpic13c, 'BPIC13C by Mauro')

# %% [markdown]
# ### Bukhsh

# %%
# Load data
pt_base_bpic13c = pd.read_csv('processtransformer\\results\\bpic13c_baseline.csv\\results_raw_results.csv')
pt_orig_bpic13c = pd.read_csv('processtransformer\\results\\bpic13c_orig.csv\\results_raw_results.csv')
pt_dda_bpic13c = pd.read_csv('processtransformer\\results\\bpic13c_cvT_0.95_0.95_dc2_augm.csv\\results_raw_results.csv')

# Map activity categorization to the one of tax
pt_orig_bpic13c = map_categorization(df_base=tax_orig_bpic13c, df_adjust=pt_orig_bpic13c)
pt_dda_bpic13c = map_categorization(df_base=tax_orig_bpic13c, df_adjust=pt_dda_bpic13c)
pt_base_bpic13c = map_categorization(df_base=tax_orig_bpic13c, df_adjust=pt_base_bpic13c)

# Plot class-wise accuracy
plot_class_accuracy(pt_orig_bpic13c, pt_dda_bpic13c, pt_base_bpic13c, 'BPIC13C by Bukhsh')

# %% [markdown]
# # BPIC15_1

# %% [markdown]
# ### Tax

# %%
# Load data
tax_base_bpic15 = pd.read_csv('tax\\code\\results\\raw_bpic15_1_baseline.txt', sep=';')
tax_orig_bpic15 = pd.read_csv('tax\\code\\results\\raw_bpic15_1_orig.txt', sep=';')
tax_dda_bpic15 = pd.read_csv('tax\\code\\results\\raw_bpic15_1_cvT_0.95_0.95_dc3_augm.txt', sep=';')

# Plot class-wise accuracy
plot_class_accuracy(tax_orig_bpic15, tax_dda_bpic15, tax_base_bpic15, 'BPIC15_1 by Tax')

# %% [markdown]
# ### Mauro

# %%
# Load data
nnpm_base_bpic15 = pd.read_csv('nnpm\\results\\raw_bpic15_1_baseline.txt', sep=';')
nnpm_orig_bpic15 = pd.read_csv('nnpm\\results\\raw_bpic15_1_orig.txt', sep=';')
nnpm_dda_bpic15= pd.read_csv('nnpm\\results\\raw_bpic15_1_cvT_0.95_0.95_dc2_augm.txt', sep=';')

# Map activity categorization to the one of tax
nnpm_orig_bpic15 = map_categorization(df_base=tax_orig_bpic15, df_adjust=nnpm_orig_bpic15)
nnpm_dda_bpic15 = map_categorization(df_base=tax_orig_bpic15, df_adjust=nnpm_dda_bpic15)
nnpm_base_bpic15 = map_categorization(df_base=tax_orig_bpic15, df_adjust=nnpm_base_bpic15)

# Plot class-wise accuracy
plot_class_accuracy(nnpm_orig_bpic15, nnpm_dda_bpic15, nnpm_base_bpic15, 'BPIC15_1 by Mauro')

# %% [markdown]
# ### Bukhsh

# %%
# Load data
pt_base_bpic15 = pd.read_csv('processtransformer\\results\\bpic15_1_baseline.csv\\results_raw_results.csv')
pt_orig_bpic15 = pd.read_csv('processtransformer\\results\\bpic15_1_orig.csv\\results_raw_results.csv')
pt_dda_bpic15 = pd.read_csv('processtransformer\\results\\bpic15_1_cvT_0.95_0.95_dc2_augm.csv\\results_raw_results.csv')

# Map activity categorization to the one of tax
pt_orig_bpic15 = map_categorization(df_base=tax_orig_bpic15, df_adjust=pt_orig_bpic15)
pt_dda_bpic15 = map_categorization(df_base=tax_orig_bpic15, df_adjust=pt_dda_bpic15)
pt_base_bpic15 = map_categorization(df_base=tax_orig_bpic15, df_adjust=pt_base_bpic15)

# Plot class-wise accuracy
plot_class_accuracy(pt_orig_bpic15, pt_dda_bpic15, pt_base_bpic15, 'BPIC15_1 by Bukhsh')
